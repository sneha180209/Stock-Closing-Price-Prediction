# %%
# Out:
# C:\Users\sneha\AppData\Local\Temp\ipykernel_19268\2339195345.py:14: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df_dis = pdr.get_data_tiingo('DIS', api_key=key)
# Mean Squared Error (MSE): 506.32943515789464
